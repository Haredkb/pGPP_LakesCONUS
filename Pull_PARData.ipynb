# %% [markdown]
# <a href="https://colab.research.google.com/github/Haredkb/pGPP_LakesCONUS/blob/main/Pull_PARData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
# prompt:  find standard deviation and average PAR across all bands from 'MODIS/061/MCD18C2' for each point in df_in use corresponding date range test_datestart to test_dateend

#Corrected Code
import ee
import pandas as pd
from google.colab import drive


# Initialize Earth Engine
ee.Authenticate()
ee.Initialize(project='par-lakes')

# Define the image collection
imageCollection = ee.ImageCollection('MODIS/061/MCD18C2')

# Define the points of interest
drive.mount('/content/drive')
df_in = pd.read_csv('/content/drive/My Drive/Projects/UNDERC/200_Data/Olesyk_Data/Olesyk_LakeMetadata_wdate.csv')
# Extract latitude and longitude to points
points = []
for index, row in df_in.iterrows():
    points.append(ee.Geometry.Point([row['Longitude_DD'], row['Latitude_DD']]))

# Extract start and end dates
time_ranges = []
for index, row in df_in.iterrows():
    start_date = row['start_date']
    end_date = row['end_date']
    time_ranges.append((start_date, end_date))

# Function to calculate average and standard deviation for each point and time range
def calculate_stats(point, start_date, end_date):
    filteredCollection = imageCollection.filterBounds(point).filterDate(start_date, end_date)

    def calculate_image_stats(image):
        stats = image.reduceRegion(
            reducer=ee.Reducer.mean().combine(reducer2=ee.Reducer.stdDev(), sharedInputs=True),
            geometry=point,
            scale=500
        )
        return image.set(stats)

    stats_list = filteredCollection.map(calculate_image_stats).toList(filteredCollection.size())
    means = []
    stddevs = []
    for i in range(stats_list.size().getInfo()):
        stats_dict = ee.Dictionary(ee.Image(stats_list.get(i)).toDictionary()).getInfo()
        for band_name in stats_dict:
            if 'PAR' in band_name and 'mean' in band_name:
                means.append(stats_dict[band_name])
            elif 'PAR' in band_name and 'stdDev' in band_name:
                stddevs.append(stats_dict[band_name])

    if means:
      average_of_means = sum(means) / len(means) if means else None
      average_of_stddevs = sum(stddevs) / len(stddevs) if stddevs else None
      return average_of_means, average_of_stddevs
    else:
      return None, None

# Loop through points and time ranges, calculate stats
data = []
for i, (point, (start_date, end_date)) in enumerate(zip(points, time_ranges)):
    average, std_dev = calculate_stats(point, start_date, end_date)
    print(f"Point {i+1}, Time range: {start_date} - {end_date}")
    if average is not None:
        print(f"Average PAR: {average}")
        print(f"Standard Deviation of PAR: {std_dev}")
        data.append([i+1, point.coordinates().getInfo(), start_date, end_date, average, std_dev])
    else:
        print("No PAR data found for this point and time range.")

# Create a Pandas DataFrame
df = pd.DataFrame(data, columns=['Point', 'Coordinates', 'Start Date', 'End Date', 'Average PAR', 'Std Dev PAR'])

# Export the DataFrame to a CSV file in Google Drive
csv_file_path = '/content/drive/My Drive/Projects/UNDERC/200_Data/Olesyk_Data/point_stats_par.csv'
df.to_csv(csv_file_path, index=False)

print(f"DataFrame exported to: {csv_file_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Point 1, Time range: 2010-04-23 - 2010-09-29
# Average PAR: 109.56558685910261
# Standard Deviation of PAR: 0.0
# Point 2, Time range: 2013-06-13 - 2013-09-13
# Average PAR: 102.76714062269615
# Standard Deviation of PAR: 0.0
# Point 3, Time range: 2018-05-08 - 2018-11-06
# Average PAR: 80.48762468603736
# Standard Deviation of PAR: 0.0
# Point 4, Time range: 2013-01-01 - 2013-12-31
# Average PAR: 43.19794358245521
# Standard Deviation of PAR: 0.0
# Point 5, Time range: 2013-05-01 - 2013-11-30
# Average PAR: 78.90820928771451
# Standard Deviation of PAR: 0.0
# Point 6, Time range: 2013-06-12 - 2013-11-24
# Average PAR: 53.279846063721926
# Standard Deviation of PAR: 0.0
# Point 7, Time range: 2014-05-06 - 2014-10-16
# Average PAR: 99.0064223931811
# Standard Deviation of PAR: 0.0
# Point 8, Time range: 2012-05-28 - 2012-10-26
# Average PAR: 55.86426351651155
# Standard Deviation of PAR: 0.0
# Point 9, Time range: 2013-05-08 - 2013-10-15
# Average PAR: 68.20864915033698
# Standard Deviation of PAR: 0.0
# Point 10, Time range: 2016-03-30 - 2016-12-01
# Average PAR: 84.76142270822737
# Standard Deviation of PAR: 0.0
# Point 11, Time range: 2013-05-21 - 2013-07-31
# Average PAR: 109.29128864953216
# Standard Deviation of PAR: 0.0
# Point 12, Time range: 2015-01-02 - 2015-12-29
# Average PAR: 55.027141713099994
# Standard Deviation of PAR: 0.0
# Point 13, Time range: 2012-06-05 - 2012-10-24
# Average PAR: 54.49654681479622
# Standard Deviation of PAR: 0.0
# Point 14, Time range: 2012-05-31 - 2012-10-24
# Average PAR: 56.30889931380787
# Standard Deviation of PAR: 0.0
# Point 15, Time range: 2017-10-01 - 2018-05-01
# Average PAR: 93.69605205287138
# Standard Deviation of PAR: 0.0
# Point 16, Time range: 2016-07-20 - 2016-10-27
# Average PAR: 84.57459397065321
# Standard Deviation of PAR: 0.0
# Point 17, Time range: 2013-06-09 - 2013-11-18
# Average PAR: 78.65555112376626
# Standard Deviation of PAR: 0.0
# Point 18, Time range: 2013-01-14 - 2013-11-30
# Average PAR: 55.29420940929849
# Standard Deviation of PAR: 0.0
# Point 19, Time range: 2019-05-29 - 2019-09-25
# Average PAR: 70.99058630607803
# Standard Deviation of PAR: 0.0
# Point 20, Time range: 2008-03-01 - 2009-02-27
# Average PAR: 89.33694313123716
# Standard Deviation of PAR: 0.0
# Point 21, Time range: 2008-06-13 - 2008-10-11
# Average PAR: 97.45513882236556
# Standard Deviation of PAR: 0.0
# Point 22, Time range: 2019-04-12 - 2019-12-16
# Average PAR: 92.1876930896332
# Standard Deviation of PAR: 0.0
# Point 23, Time range: 2016-05-30 - 2016-09-10
# Average PAR: 105.12359208027715
# Standard Deviation of PAR: 0.0
# Point 24, Time range: 2017-05-31 - 2017-09-14
# Average PAR: 101.11912946599834
# Standard Deviation of PAR: 0.0
# Point 25, Time range: 2017-05-30 - 2017-09-14
# Average PAR: 100.52230250891124
# Standard Deviation of PAR: 0.0
# Point 26, Time range: 2019-06-12 - 2019-10-24
# Average PAR: 124.67062619043803
# Standard Deviation of PAR: 0.0
# Point 27, Time range: 2013-05-21 - 2013-09-12
# Average PAR: 100.80415472832688
# Standard Deviation of PAR: 0.0
# Point 28, Time range: 2017-06-04 - 2017-09-14
# Average PAR: 99.32493909784392
# Standard Deviation of PAR: 0.0
# Point 29, Time range: 2016-05-10 - 2016-10-22
# Average PAR: 90.14534190237296
# Standard Deviation of PAR: 0.0
# Point 30, Time range: 2008-05-30 - 2008-11-04
# Average PAR: 88.06976839664239
# Standard Deviation of PAR: 0.0
# Point 31, Time range: 2013-05-30 - 2013-10-30
# Average PAR: 118.18831711492861
# Standard Deviation of PAR: 0.0
# Point 32, Time range: 2006-04-11 - 2006-11-21
# Average PAR: 69.0595074833774
# Standard Deviation of PAR: 0.0
# Point 33, Time range: 2010-05-05 - 2010-12-30
# Average PAR: 53.10520030717778
# Standard Deviation of PAR: 0.0
# Point 34, Time range: 2007-04-19 - 2007-09-30
# Average PAR: 76.5697054422312
# Standard Deviation of PAR: 0.0
# Point 35, Time range: 2017-05-30 - 2017-09-14
# Average PAR: 100.52230250891124
# Standard Deviation of PAR: 0.0
# Point 36, Time range: 2018-05-09 - 2018-10-31
# Average PAR: 93.92075001766905
# Standard Deviation of PAR: 0.0
# Point 37, Time range: 2008-01-01 - 2008-12-30
# Average PAR: 78.86314753970198
# Standard Deviation of PAR: 0.0
# Point 38, Time range: 2013-05-30 - 2013-10-30
# Average PAR: 90.56275093341185
# Standard Deviation of PAR: 0.0
# Point 39, Time range: 2018-08-01 - 2018-10-02
# Average PAR: 75.07660873480621
# Standard Deviation of PAR: 0.0
# Point 40, Time range: 2003-03-20 - 2003-10-15
# Average PAR: 83.27925823712677
# Standard Deviation of PAR: 0.0
# Point 41, Time range: 2013-05-08 - 2013-10-15
# Average PAR: 68.90121108520343
# Standard Deviation of PAR: 0.0
# Point 42, Time range: 2017-05-30 - 2017-09-14
# Average PAR: 99.14196788624068
# Standard Deviation of PAR: 0.0
# Point 43, Time range: 2019-05-30 - 2019-10-27
# Average PAR: 92.4336976008614
# Standard Deviation of PAR: 0.0
# Point 44, Time range: 2001-05-05 - 2001-10-27
# Average PAR: 95.81218104733593
# Standard Deviation of PAR: 0.0
# Point 45, Time range: 2019-05-25 - 2019-08-24
# Average PAR: 115.63980895935835
# Standard Deviation of PAR: 0.0
# Point 46, Time range: 2019-05-25 - 2019-07-01
# Average PAR: 115.10220494624731
# Standard Deviation of PAR: 0.0
# Point 47, Time range: 2008-03-21 - 2008-12-31
# No PAR data found for this point and time range.
# Point 48, Time range: 2018-09-28 - 2018-10-16
# Average PAR: 30.17123476467613
# Standard Deviation of PAR: 0.0
# Point 49, Time range: 2019-07-05 - 2019-10-11
# Average PAR: 87.5408428715618
# Standard Deviation of PAR: 0.0
# Point 50, Time range: 2008-08-25 - 2009-07-23
# Average PAR: 74.54238932559137
# Standard Deviation of PAR: 0.0
# Point 51, Time range: 2007-07-14 - 2008-07-09
# Average PAR: 73.84980378583154
# Standard Deviation of PAR: 0.0
# Point 52, Time range: 2010-05-07 - 2010-12-19
# Average PAR: 58.53281751067619
# Standard Deviation of PAR: 0.0
# Point 53, Time range: 2013-05-30 - 2013-10-30
# Average PAR: 86.9323035178792
# Standard Deviation of PAR: 0.0
# Point 54, Time range: 2016-05-19 - 2016-10-24
# Average PAR: 77.47850502579462
# Standard Deviation of PAR: 0.0
# Point 55, Time range: 2017-05-30 - 2017-09-25
# Average PAR: 106.63120838468875
# Standard Deviation of PAR: 0.0
# Point 56, Time range: 2008-05-09 - 2008-10-26
# Average PAR: 94.50453187393792
# Standard Deviation of PAR: 0.0
# Point 57, Time range: 2013-05-30 - 2013-10-30
# Average PAR: 74.68876817016451
# Standard Deviation of PAR: 0.0
# Point 58, Time range: 2006-04-12 - 2006-11-23
# Average PAR: 69.00394183386014
# Standard Deviation of PAR: 0.0
# Point 59, Time range: 2019-03-31 - 2019-12-12
# Average PAR: 92.56506447310278
# Standard Deviation of PAR: 0.0
# Point 60, Time range: 2008-05-01 - 2008-10-30
# Average PAR: 86.35754565075858
# Standard Deviation of PAR: 0.0
# Point 61, Time range: 2007-10-09 - 2008-09-26
# Average PAR: 71.9780984000254
# Standard Deviation of PAR: 0.0
# Point 62, Time range: 2008-05-30 - 2008-11-10
# Average PAR: 85.46098237893567
# Standard Deviation of PAR: 0.0
# Point 63, Time range: 2017-05-04 - 2017-11-19
# Average PAR: 111.53561426774041
# Standard Deviation of PAR: 0.0
# Point 64, Time range: 2008-05-14 - 2008-11-30
# Average PAR: 62.030478499663296
# Standard Deviation of PAR: 0.0
# Point 65, Time range: 2016-06-01 - 2016-09-11
# Average PAR: 105.27542237002476
# Standard Deviation of PAR: 0.0
# Point 66, Time range: 2017-05-30 - 2017-09-14
# Average PAR: 100.52230250891124
# Standard Deviation of PAR: 0.0
# Point 67, Time range: 2013-05-30 - 2013-10-30
# Average PAR: 94.67562094346586
# Standard Deviation of PAR: 0.0
# Point 68, Time range: 2016-12-31 - 2017-12-30
# Average PAR: 60.16003297664389
# Standard Deviation of PAR: 0.0
# DataFrame exported to: /content/drive/My Drive/Projects/UNDERC/200_Data/Olesyk_Data/point_stats_par.csv
